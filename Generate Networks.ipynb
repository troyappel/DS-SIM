# %%
from graphs import *
from simulator import *

# %%
m_nodes = [MachineNode(5, 0), MachineNode(3, 1), MachineNode(2, 2)]
m_edges = [MachineEdge(0, 1), MachineEdge(1, 2), MachineEdge(2, 0)]
mg = MachineGraph(m_nodes, m_edges)

# %%
mg.draw(blocking=False)
# Out:
# WHOOO
